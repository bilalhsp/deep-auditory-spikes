# %%
# ------------------  set up logging ----------------------
import logging
from auditory_cortex.utils import set_up_logging
set_up_logging('info')

from auditory_cortex.plotters import tikzplots
# %matplotlib inline

# %%
threshold=1.0
save_tikz = False
lag = 200

multicorrect=True
correction_method='fdr_bh' #'fdr_bh' #

y_lims = [0.18, 0.85]
sig_offset_y=0.80
arch_ind_offset=0.85

# %% [markdown]
# ### layerwise plots

# %% [markdown]
# #### timit

# %%
model_names = [
	'wav2letter_modified',
	'wav2vec2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
]
bin_width = 50

trained_identifier = f'ucsf_timit_trf_lags{lag}_bw50_ahmed_25'
untrained_identifiers = [trained_identifier.replace('ucsf', 'ucsf_reset')]
tikz_indicator = f'trf{lag}'
baseline_identifier = f"coch_ucsf_timit_trf_lags{lag}_bw50_ahmed_25"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
if 'mVocs' in trained_identifier:
	mVocs=True
else:
	mVocs=False
normalized=True
tikzplots.plot_trained_vs_shuffled_network_results(
		model_names=model_names,
		normalized=normalized,
		threshold=threshold,
		untrained_identifiers = untrained_identifiers,
		trained_identifier = trained_identifier,
		baseline_identifier=baseline_identifier,
		indicate_significance=True,
		plot_normalized=False,
		display_dotted_lines=False,
		mVocs=mVocs,
		save_tikz=save_tikz,
		arch_ind_lw=8,
		sig_ind_size=1,
        sig_offset_y=sig_offset_y,
        arch_ind_offset=arch_ind_offset,
        y_lims=y_lims,
		tikz_indicator=tikz_indicator,
		bin_width=bin_width,
		plot_baseline=True,
		use_stat_inclusion=False,
        multicorrect=multicorrect,
        correction_method=correction_method,
)
# Out:
# INFO:Created a temporary directory at /tmp/tmpds8mg60e
# INFO:Writing /tmp/tmpds8mg60e/_remote_module_non_scriptable.py
# WARNING:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#
# INFO:Plotting trained and shuffled distributions for wav2letter_modified
# /bin/sh: line 1: sox: command not found
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6161236418209896, occurs at x_coordinate: 3
# INFO:Peak corr (max): 0.9484646849354336, occurs at x_coordinate: 2
# INFO:Peak corr (median): 0.405719032065362, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.956725002924982, occurs at x_coordinate: 0
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 13..
# INFO:Trained-STRF: # of significant levels 7..
# INFO:Plotting trained and shuffled distributions for wav2vec2
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6171876494793219, occurs at x_coordinate: 4
# INFO:Peak corr (max): 0.9131672642641182, occurs at x_coordinate: 8
# INFO:Peak corr (median): 0.4557212206746827, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.9478467480846744, occurs at x_coordinate: 1
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 19..
# INFO:Trained-STRF: # of significant levels 10..
# INFO:Plotting trained and shuffled distributions for speech2text
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6030245269258558, occurs at x_coordinate: 7
# INFO:Peak corr (max): 0.9086125332666504, occurs at x_coordinate: 4
# INFO:Peak corr (median): 0.5173315422483262, occurs at x_coordinate: 13
# INFO:Peak corr (max): 0.887031564914155, occurs at x_coordinate: 10
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 10..
# INFO:Trained-STRF: # of significant levels 9..
# INFO:Plotting trained and shuffled distributions for whisper_tiny
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6179598429555686, occurs at x_coordinate: 2
# INFO:Peak corr (max): 0.9298824673090876, occurs at x_coordinate: 2
# INFO:Peak corr (median): 0.5778917628887853, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.8780196615200477, occurs at x_coordinate: 2
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 3..
# INFO:Trained-STRF: # of significant levels 3..
# INFO:Plotting trained and shuffled distributions for whisper_base
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6199326296804397, occurs at x_coordinate: 2
# INFO:Peak corr (max): 0.9310358362694008, occurs at x_coordinate: 1
# INFO:Peak corr (median): 0.5813305591720492, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.8976564977469133, occurs at x_coordinate: 4
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 4..
# INFO:Trained-STRF: # of significant levels 4..
# INFO:Plotting trained and shuffled distributions for deepspeech2
# ucsf_timit_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (286,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.644672780948959, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.9747498768971894, occurs at x_coordinate: 1
# INFO:Peak corr (median): 0.5848013406941718, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.974159280992854, occurs at x_coordinate: 5
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5455325994129347, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8866673710022782, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 4..
# INFO:Trained-STRF: # of significant levels 4..

# %% [markdown]
# #### mVocs

# %%
model_names = [
	'wav2letter_modified',
	'wav2vec2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
]
bin_width = 50
trained_identifier = f'ucsf_mVocs_trf_lags{lag}_bw50_ahmed_25'
untrained_identifiers = [trained_identifier.replace('ucsf', 'ucsf_reset')]
tikz_indicator = f'trf{lag}'
baseline_identifier = f"coch_ucsf_mVocs_trf_lags{lag}_bw50_ahmed_25"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
if 'mVocs' in trained_identifier:
	mVocs=True
else:
	mVocs=False
normalized=True
tikzplots.plot_trained_vs_shuffled_network_results(
		model_names=model_names,
		normalized=normalized,
		threshold=threshold,
		untrained_identifiers = untrained_identifiers,
		trained_identifier = trained_identifier,
		# areas = ['core', 'belt', 'parabelt'],
		baseline_identifier=baseline_identifier,
		indicate_significance=True,
		plot_normalized=False,
		display_dotted_lines=False,
		mVocs=mVocs,
		save_tikz=save_tikz,
		arch_ind_lw=8,
		sig_ind_size=1,
        sig_offset_y=sig_offset_y,
        arch_ind_offset=arch_ind_offset,
        y_lims=y_lims,
		tikz_indicator=tikz_indicator,
		bin_width=bin_width,
		plot_baseline=True,
		use_stat_inclusion=False,
        multicorrect=multicorrect,
        correction_method=correction_method,
)
# Out:
# INFO:Plotting trained and shuffled distributions for wav2letter_modified
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.7065401614269363, occurs at x_coordinate: 4
# INFO:Peak corr (max): 0.9867347732251618, occurs at x_coordinate: 9
# INFO:Peak corr (median): 0.49044783830339045, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8768205630068534, occurs at x_coordinate: 12
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 14..
# INFO:Trained-STRF: # of significant levels 10..
# INFO:Plotting trained and shuffled distributions for wav2vec2
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6551226528534329, occurs at x_coordinate: 10
# INFO:Peak corr (max): 0.9894297510163762, occurs at x_coordinate: 10
# INFO:Peak corr (median): 0.5448738123936285, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.8465096709939165, occurs at x_coordinate: 1
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 20..
# INFO:Trained-STRF: # of significant levels 4..
# INFO:Plotting trained and shuffled distributions for speech2text
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.641112395641305, occurs at x_coordinate: 7
# INFO:Peak corr (max): 0.9657849912669983, occurs at x_coordinate: 0
# INFO:Peak corr (median): 0.5798546337592176, occurs at x_coordinate: 11
# INFO:Peak corr (max): 0.97002109124875, occurs at x_coordinate: 6
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 12..
# INFO:Trained-STRF: # of significant levels 0..
# INFO:Plotting trained and shuffled distributions for whisper_tiny
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.6992457689454777, occurs at x_coordinate: 2
# INFO:Peak corr (max): 1.0147213266653152, occurs at x_coordinate: 4
# INFO:Peak corr (median): 0.6738986366761253, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.982289858387414, occurs at x_coordinate: 5
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 4..
# INFO:Trained-STRF: # of significant levels 4..
# INFO:Plotting trained and shuffled distributions for whisper_base
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.7046635129325595, occurs at x_coordinate: 2
# INFO:Peak corr (max): 0.9984608712829094, occurs at x_coordinate: 4
# INFO:Peak corr (median): 0.6811360411816281, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.9738604928861992, occurs at x_coordinate: 5
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 7..
# INFO:Trained-STRF: # of significant levels 7..
# INFO:Plotting trained and shuffled distributions for deepspeech2
# ucsf_mVocs_trf_lags200_bw50_ahmed_25
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Number of channels returned: (360,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:Peak corr (median): 0.7175632012455694, occurs at x_coordinate: 2
# INFO:Peak corr (max): 0.9917312664798736, occurs at x_coordinate: 3
# INFO:Peak corr (median): 0.6575982777672634, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9363396589844, occurs at x_coordinate: 0
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.640810206336317, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9349453263354016, occurs at x_coordinate: 0
# INFO:Applying multiple correction to p-values, using fdr_bh method.
# INFO:Trained-untrained: # of significant levels 5..
# INFO:Trained-STRF: # of significant levels 5..

# %% [markdown]
# ### summary of peak correlations

# %% [markdown]
# #### timit

# %%
model_names = [
	'wav2letter_modified',
	'wav2vec2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
	]
trained_identifier = f'ucsf_timit_trf_lags{lag}_bw50_ahmed_25'
untrained_identifiers = trained_identifier.replace('ucsf', 'ucsf_reset')
baseline_identifier = f"coch_ucsf_timit_trf_lags{lag}_bw50_ahmed_25"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
mVocs=False
tikz_indicator = f'trf{lag}'
bin_width = 50
tikzplots.plot_correlations_summary(
	model_names,
	trained_identifier,
    untrained_identifiers,
    baseline_identifier,
    threshold=threshold,
	bin_width=bin_width,
	mVocs=mVocs,
    tikz_indicator=tikz_indicator,
    y_lims=y_lims,
	width = 0.4,
	alpha=0.4,
	save_tikz=save_tikz
	)
# Out:
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 3
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 0
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 4
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 7
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 13
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 2
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 2
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 286
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 0
# INFO:Number of sig. neurons = 286
# INFO:Filtering 'normalizer' using multiple of 1.000 with std dev ...
# model_name 'STRF' not recognizable!!!

# %% [markdown]
# #### mVocs

# %%
model_names = [
	'wav2letter_modified',
	'wav2vec2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
	]
trained_identifier = f'ucsf_mVocs_trf_lags{lag}_bw50_ahmed_25'
untrained_identifiers = trained_identifier.replace('ucsf', 'ucsf_reset')
baseline_identifier = f"coch_ucsf_mVocs_trf_lags{lag}_bw50_ahmed_25"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
mVocs=True
tikz_indicator = f'trf{lag}'
bin_width = 50
tikzplots.plot_correlations_summary(
	model_names,
	trained_identifier,
    untrained_identifiers,
    baseline_identifier,
    threshold=threshold,
	bin_width=bin_width,
    tikz_indicator=tikz_indicator,
	mVocs=mVocs,
    y_lims=y_lims,
	width = 0.4,
	alpha=0.4,
	save_tikz=save_tikz
	)
# Out:
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 4
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 0
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 10
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 7
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 11
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 2
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 2
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 1
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 2
# INFO:Number of sig. neurons = 360
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# INFO:At bin_width: 50, layer with peak median is: 0
# INFO:Number of sig. neurons = 360
# INFO:Filtering 'mVocs_normalizer' using multiple of 1.000 with std dev ...
# model_name 'STRF' not recognizable!!!
