# %%
# ------------------  set up logging ----------------------
import logging
from auditory_cortex.utils import set_up_logging
set_up_logging('info')

# %matplotlib inline

# %%
save_tikz=False
threshold=0.5
lag = 200

# %% [markdown]
# ### models separately

# %% [markdown]
# #### timit

# %%
from auditory_cortex.plotters import tikzplots
model_names = [
    'wav2letter_modified',
    'wav2vec2',
    'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
	]
trained_identifier = f'ucsf_timit_trf_lags{lag}_bw50_ahmed_25'
tikz_indicator = f'trf{lag}'
bin_width = 50
mVocs = False
tikzplots.plot_peak_layer_histograms(
	model_names,
	trained_identifier,
	bin_width=bin_width,
	mVocs=mVocs,
	threshold = threshold,
    tikz_indicator=tikz_indicator,
    save_tikz=save_tikz,
	fontsize=8,
	figsize=(2.5,2),
	)
# Out:
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 300
# INFO:Number of channels in non-primary: 104
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/1688863097.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(

# %% [markdown]
# #### mVocs

# %%
from auditory_cortex.plotters import tikzplots
model_names = [
    'wav2letter_modified',
    'wav2vec2',
    'speech2text',
	'whisper_tiny',
	'whisper_base',
	'deepspeech2',
	]
trained_identifier = f'ucsf_mVocs_trf_lags{lag}_bw50_ahmed_25'
tikz_indicator = f'trf{lag}'
bin_width = 50
mVocs = True
tikzplots.plot_peak_layer_histograms(
	model_names,
	trained_identifier,
	bin_width=bin_width,
	mVocs=mVocs,
	threshold =threshold,
	save_tikz=save_tikz,
    tikz_indicator=tikz_indicator,
	fontsize=8,
	figsize=(2.5,2),
	)
# Out:
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels in core: 315
# INFO:Number of channels in non-primary: 174
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
# /tmp/ipykernel_1974712/445573102.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms(
