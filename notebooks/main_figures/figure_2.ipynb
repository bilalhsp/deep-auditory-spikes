# %%
# ------------------  set up logging ----------------------
import logging
from auditory_cortex.utils import set_up_logging
set_up_logging('info')

from auditory_cortex.plotters import tikzplots
from auditory_cortex.plotters.plotter_utils import PlotterUtils
# %matplotlib inline
# Out:
# INFO:Created a temporary directory at /tmp/tmpypa2vyso
# INFO:Writing /tmp/tmpypa2vyso/_remote_module_non_scriptable.py
# WARNING:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
# /bin/sh: line 1: sox: command not found

# %%
model_names = ['whisper_base', 'wav2vec2' ]
sessions = [200206, 180731] 
highlight_sessions = {}
for sess, model in zip(sessions, model_names):
    color = PlotterUtils.get_model_specific_color(model)
    highlight_sessions[sess] = color

save_tikz = False
tikzplots.plot_session_coordinates(highlight_sessions, save_tikz=save_tikz)
# Out:
# /home/ahmedb/.conda/envs/cent7/2020.11-py38/wav2letter/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1026: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)

# %%
model_names = ['whisper_base', 'wav2vec2' ]
sessions = [200206, 180731] 
chs = [32, 7] # 180807, ch-1 # 180731, ch-7
# sent_ids = [218, 12]
sent_ids = [308, 56]
## 56, 212, 308
save_tikz = False
bin_width = 50
tikzplots.plot_spectrogram_spikes_counts(
	model_names=model_names,
	sessions=sessions,
	chs=chs,
	bin_width=bin_width,
	sent_ids=sent_ids,
	save_tikz=save_tikz
)
# Out:
# INFO:NeuralData:  Creating object for session: 200206 ...
# INFO:Done.
# result saved at: /depot/jgmakin/data/auditory_cortex/results/tikz_plots/spectrogram_sent308.tex
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO:creating Dataset for timit data.
# INFO:Loading data for session at bin_width-50ms.
# INFO:Reading features for model: whisper_base
